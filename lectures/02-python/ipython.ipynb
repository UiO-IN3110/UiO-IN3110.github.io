# %% [markdown]
# # The Jupyter notebook
#
# Jupyter is the name for this notebook interface, and the document format.
#
# <img src="jupyter-logo.png" width=300/>
#
#
# Notebooks can contain [Markdown](https://help.github.com/articles/markdown-basics/) like this cell here,
# as well as mathematics rendered with [mathjax](https://mathjax.org):
#
# $$
# \frac{1}{\Bigl(\sqrt{\phi \sqrt{5}}-\phi\Bigr) e^{\frac25 \pi}} =
# 1+\frac{e^{-2\pi}} {1+\frac{e^{-4\pi}} {1+\frac{e^{-6\pi}}
# {1+\frac{e^{-8\pi}} {1+\ldots} } } }
# $$

# %%
# !head -n 32 "ipython.ipynb"
# Out:
# {
#  "cells": [
#   {
#    "cell_type": "markdown",
#    "metadata": {},
#    "source": [
#     "# The Jupyter notebook\n",
#     "\n",
#     "[IPython](https://ipython.org) provides a **kernel** for [Jupyter](https://jupyter.org).\n",
#     "Jupyter is the name for this notebook interface,\n",
#     "and the document format.\n",
#     "\n",
#     "<img src=\"jupyter-logo.png\" width=300/>\n",
#     "\n",
#     "\n",
#     "Notebooks can contain [Markdown](https://help.github.com/articles/markdown-basics/) like this cell here,\n",
#     "as well as mathematics rendered with [mathjax](https://mathjax.org):\n",
#     "\n",
#     "$$\n",
#     "\\frac{1}{\\Bigl(\\sqrt{\\phi \\sqrt{5}}-\\phi\\Bigr) e^{\\frac25 \\pi}} =\n",
#     "1+\\frac{e^{-2\\pi}} {1+\\frac{e^{-4\\pi}} {1+\\frac{e^{-6\\pi}}\n",
#     "{1+\\frac{e^{-8\\pi}} {1+\\ldots} } } } \n",
#     "$$"
#    ]
#   },
#   {
#    "cell_type": "code",
#    "execution_count": 1,
#    "metadata": {
#     "scrolled": true
#    },
#    "outputs": [

# %% [markdown]
# [nbviewer](https://nbviewer.org) is a service that renders notebooks to HTML,
# for sharing and reading notebooks on the Internet.
#
# EDIT: [This notebook](https://nbviewer.jupyter.org/github/minrk/inf3331-ipython/blob/master/Intro%20to%20IPython.ipynb) on nbviewer.
#
# You can also convert notebooks to HTML and other formats locally with `jupyter nbconvert`.

# %% [markdown]
# # IPython: beyond plain Python

# %% [markdown]
# When executing code in IPython, all valid Python syntax works as-is, but IPython provides a number of features designed to make the interactive experience more fluid and efficient.

# %% [markdown]
# ## First things first: running code, getting help

# %% [markdown]
# In the notebook, to run a cell of code, hit `Shift-Enter`. This executes the cell and puts the cursor in the next cell below, or makes a new one if you are at the end.  Alternately, you can use:
#
# - `Alt-Enter` (or `option-Enter`) to force the creation of a new cell unconditionally (useful when inserting new content in the middle of an existing notebook).
# - `Control-Enter` executes the cell and keeps the cursor in the same cell, useful for quick experimentation of snippets that you don't need to keep permanently.

# %%
print("Hi")
# Out:
# Hi

# %%
import time
for i in range(5):
    print(i, end=' ')
    time.sleep(1)
# Out:
# 0 1 2 3 4

# %%
i
# Out:
# 4

# %% [markdown]
# Getting help:

# %% [markdown]
# Typing `object_name?` will print all sorts of details about any object, including docstrings, function definition lines (for call arguments) and constructor details for classes.

# %%
import numpy as np
np.asarray?

# %% [markdown]
# use two question marks `??` to see the source code:

# %%
np.asarray??

# %% [markdown]
# ## Tab completion

# %% [markdown]
# Tab completion, especially for attributes, is a convenient way to explore the structure of any object you’re dealing with. Type `object_name.<TAB>` to view the object’s attributes. Besides Python objects and keywords, tab completion also works on file and directory names.

# %%
from PIL import Image

# %% [markdown]
# ## Accessing the underlying operating system
#
# We can use `cat` to view the contents of a file:

# %%
# !cat hw.py
# Out:
# #!/usr/bin/env python3
#
# from math import sin
# import sys
#
# x = float(sys.argv[1])
# sin_x = sin(x)
#
# print(f"Hello, sin({x:g}) = {sin_x:.3f}")

# %%
import os
print(os.getcwd())
# Out:
# /home/ingeborg/Code/Teaching/IN3110/lectures/02-python

# %%
import subprocess
p = subprocess.Popen(['ls', '-l'], stdout=subprocess.PIPE)
stdout, _ = p.communicate()
print(stdout.decode())
# Out:
# total 2020
# -rw-rw-r-- 1 ingeborg ingeborg  15450 sep.   1 09:48 exercises-Copy1.ipynb
# -rw-rw-r-- 1 ingeborg ingeborg  12814 sep.  12 20:39 exercises.ipynb
# drwxrwxr-x 2 ingeborg ingeborg   4096 aug.  30 14:59 figs
# -rw-rw-r-- 1 ingeborg ingeborg    178 sep.   1 09:37 hw-exercise.py
# -rwxrwxr-x 1 ingeborg ingeborg    139 aug.  31 21:20 hw.py
# -rw-rw-r-- 1 ingeborg ingeborg  13382 sep.  14 21:36 ipython.ipynb
# -rw-rw-r-- 1 ingeborg ingeborg  22868 aug.  24 16:39 jupyter-logo.png
# -rw-rw-r-- 1 ingeborg ingeborg  11455 sep.   1 10:02 l2_recap_and_plan.ipynb
# -rw-rw-r-- 1 ingeborg ingeborg 582647 sep.   1 10:01 l2_recap_and_plan.slides.html
# -rw-rw-r-- 1 ingeborg ingeborg     61 aug.  31 22:26 mod.py
# -rw-rw-r-- 1 ingeborg ingeborg    740 aug.  24 16:39 myNumber_test.py
# -rwxrwxr-x 1 ingeborg ingeborg    823 aug.  24 16:39 point.py
# drwxrwxr-x 2 ingeborg ingeborg   4096 aug.  31 22:26 __pycache__
# -rw-rw-r-- 1 ingeborg ingeborg  15011 sep.  12 20:39 python_summary-classes.ipynb
# -rw-rw-r-- 1 ingeborg ingeborg 618640 sep.   1 11:27 python_summary-classes.slides.html
# -rw-rw-r-- 1 ingeborg ingeborg  49134 aug.  31 21:56 python_summary.ipynb
# -rw-rw-r-- 1 ingeborg ingeborg 669754 sep.   1 10:24 python_summary.slides.html
# -rwxrwxr-x 1 ingeborg ingeborg    658 aug.  24 16:39 shape.py
# -rw-rw-r-- 1 ingeborg ingeborg     68 aug.  31 22:27 test.txt

# %%
# !pwd
# Out:
# /home/ingeborg/Code/Teaching/IN3110/lectures/02-python

# %%
# !ls -la
# Out:
# total 2032
# drwxrwxr-x  5 ingeborg ingeborg   4096 sep.  14 21:36 .
# drwxrwxr-x 19 ingeborg ingeborg   4096 sep.  14 21:33 ..
# -rw-rw-r--  1 ingeborg ingeborg  15450 sep.   1 09:48 exercises-Copy1.ipynb
# -rw-rw-r--  1 ingeborg ingeborg  12814 sep.  12 20:39 exercises.ipynb
# drwxrwxr-x  2 ingeborg ingeborg   4096 aug.  30 14:59 figs
# -rw-rw-r--  1 ingeborg ingeborg    178 sep.   1 09:37 hw-exercise.py
# -rwxrwxr-x  1 ingeborg ingeborg    139 aug.  31 21:20 hw.py
# drwxrwxr-x  2 ingeborg ingeborg   4096 sep.   1 09:32 .ipynb_checkpoints
# -rw-rw-r--  1 ingeborg ingeborg  13382 sep.  14 21:36 ipython.ipynb
# -rw-rw-r--  1 ingeborg ingeborg  22868 aug.  24 16:39 jupyter-logo.png
# -rw-rw-r--  1 ingeborg ingeborg  11455 sep.   1 10:02 l2_recap_and_plan.ipynb
# -rw-rw-r--  1 ingeborg ingeborg 582647 sep.   1 10:01 l2_recap_and_plan.slides.html
# -rw-rw-r--  1 ingeborg ingeborg     61 aug.  31 22:26 mod.py
# -rw-rw-r--  1 ingeborg ingeborg    740 aug.  24 16:39 myNumber_test.py
# -rwxrwxr-x  1 ingeborg ingeborg    823 aug.  24 16:39 point.py
# drwxrwxr-x  2 ingeborg ingeborg   4096 aug.  31 22:26 __pycache__
# -rw-rw-r--  1 ingeborg ingeborg  15011 sep.  12 20:39 python_summary-classes.ipynb
# -rw-rw-r--  1 ingeborg ingeborg 618640 sep.   1 11:27 python_summary-classes.slides.html
# -rw-rw-r--  1 ingeborg ingeborg  49134 aug.  31 21:56 python_summary.ipynb
# -rw-rw-r--  1 ingeborg ingeborg 669754 sep.   1 10:24 python_summary.slides.html
# -rwxrwxr-x  1 ingeborg ingeborg    658 aug.  24 16:39 shape.py
# -rw-rw-r--  1 ingeborg ingeborg     68 aug.  31 22:27 test.txt

# %%
files = !ls
print("My current directory's files:")
print(files)
# Out:
# My current directory's files:
# ['exercises-Copy1.ipynb', 'exercises.ipynb', 'figs', 'hw-exercise.py', 'hw.py', 'ipython.ipynb', 'jupyter-logo.png', 'l2_recap_and_plan.ipynb', 'l2_recap_and_plan.slides.html', 'mod.py', 'myNumber_test.py', 'point.py', '__pycache__', 'python_summary-classes.ipynb', 'python_summary-classes.slides.html', 'python_summary.ipynb', 'python_summary.slides.html', 'shape.py', 'test.txt']

# %%
for f in files:
    print(f)
# Out:
# exercises-Copy1.ipynb
# exercises.ipynb
# figs
# hw-exercise.py
# hw.py
# ipython.ipynb
# jupyter-logo.png
# l2_recap_and_plan.ipynb
# l2_recap_and_plan.slides.html
# mod.py
# myNumber_test.py
# point.py
# __pycache__
# python_summary-classes.ipynb
# python_summary-classes.slides.html
# python_summary.ipynb
# python_summary.slides.html
# shape.py
# test.txt

# %% [markdown]
# ## Beyond Python: magic functions

# %% [markdown]
# The IPython 'magic' functions are a set of commands, invoked by prepending one or two `%` signs to their name, that live in a namespace separate from your normal Python variables and provide a more command-like interface.  They take flags with `--` and arguments without quotes, parentheses or commas. The motivation behind this system is two-fold:
#
# - To provide a namespace for controlling IPython itself and exposing other system-oriented functionality.
#
# - To expose a calling mode that requires minimal verbosity and typing while working interactively.  Thus the inspiration taken from the classic Unix shell style for commands.

# %% [markdown]
# Line vs cell magics:

# %%
# %timeit list(range(10000))
# Out:
# 99.9 µs ± 713 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
# %%timeit
list(range(10))
list(range(100))
# Out:
# 733 ns ± 3.95 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# Line magics can be used even inside code blocks:

# %%
for size in [10, 1000, 100_000, 1_000_000]:
    print(f'size: {size:10}', end=' ')
    # %timeit list(range(size))
# Out:
# size:         10 204 ns ± 1.37 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)
# size:       1000 8.92 µs ± 246 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# size:     100000 1.04 ms ± 9.33 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# size:    1000000 22.9 ms ± 2.67 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# %timeit time.sleep(1)
# Out:
# 1 s ± 604 µs per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %timeit?

# %% [markdown]
# We can use a magic to write a file.

# %%
# %%writefile test.txt
# This is a test file!
# It can contain anything I want...
#
# And more...
# Out:
# Overwriting test.txt

# %%
# !cat test.txt
# Out:
# This is a test file!
# It can contain anything I want...
#
# And more...

# %% [markdown]
# Let's see what other magics are currently defined in the system:

# %%
# %lsmagic
# Out:
# Available line magics:
# %alias  %alias_magic  %autoawait  %autocall  %automagic  %autosave  %bookmark  %cat  %cd  %clear  %colors  %conda  %config  %connect_info  %cp  %debug  %dhist  %dirs  %doctest_mode  %ed  %edit  %env  %gui  %hist  %history  %killbgscripts  %ldir  %less  %lf  %lk  %ll  %load  %load_ext  %loadpy  %logoff  %logon  %logstart  %logstate  %logstop  %ls  %lsmagic  %lx  %macro  %magic  %man  %matplotlib  %mkdir  %more  %mv  %notebook  %page  %pastebin  %pdb  %pdef  %pdoc  %pfile  %pinfo  %pinfo2  %pip  %popd  %pprint  %precision  %prun  %psearch  %psource  %pushd  %pwd  %pycat  %pylab  %qtconsole  %quickref  %recall  %rehashx  %reload_ext  %rep  %rerun  %reset  %reset_selective  %rm  %rmdir  %run  %save  %sc  %set_env  %store  %sx  %system  %tb  %time  %timeit  %unalias  %unload_ext  %who  %who_ls  %whos  %xdel  %xmode
#
# Available cell magics:
# %%!  %%HTML  %%SVG  %%bash  %%capture  %%debug  %%file  %%html  %%javascript  %%js  %%latex  %%markdown  %%perl  %%prun  %%pypy  %%python  %%python2  %%python3  %%ruby  %%script  %%sh  %%svg  %%sx  %%system  %%time  %%timeit  %%writefile
#
# Automagic is ON, % prefix IS NOT needed for line magics.

# %% [markdown]
# ## Plotting in the notebook

# %% [markdown]
# This magic configures matplotlib to render its figures inline:

# %%
# %matplotlib notebook

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(0, 2*np.pi, 300)
y = np.sin(x**2)
plt.plot(x, y)
plt.title("A little chirp")
fig = plt.gcf()
# Out:
# <img src="data:image/png;base64,..." width="640">
