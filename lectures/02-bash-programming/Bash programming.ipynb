# %% [markdown]
# # First some organisational stuff

# %% [markdown]
# ## Assignments 1
#
# * Deadline: Today at midnight
# * Make sure that your solution is pushed to
#
#   `https://github.com/UiO-INF3331/INF3331-username`.
# * If you have problems accessing your repo, talk to me during the break/after the lecture.

# %% [markdown]
# ## Assignments 2
#
# * Assignment 2 is online now.
# * Topic: Bash scripting (lecture today).

# %% [markdown]
# # Bash programming

# %% [markdown]
# ## Overview of Unix shells
#
#   * The original scripting languages were (extensions of) command interpreters in operating systems
#
#   * Primary example: Unix shells
#
#   * Bourne shell (`sh`) was the first major shell
#     * C and TC shell (`csh` and `tcsh`) had improved command interpreters, but were less popular than Bourne shell for programming
#     * Bourne Again shell (Bash/`bash`) is a GNU/FSF improvement of Bourne shell
#     * Other Bash-like shells: Dash (`dash`), Korn shell (`ksh`), Z shell (`zsh`)
#
#   * Bash is the dominating Unix shell today

# %% [markdown]
# ## Why learn Bash?
#
#   * Learning Bash means learning Unix
#
#   * Learning Bash means learning the roots of scripting (Bourne shell is a subset of Bash)
#
#   * Shell scripts, especially in Bourne shell and Bash, are frequently encountered on Unix systems
#
#   * Bash is widely available (open source) and the dominating command interpreter and scripting language on today's Unix systems

# %% [markdown]
# ## Why learn Bash? (2)
#
# * Shell scripts evolve naturally from a workflow:
#   * A sequence of commands you use often are placed in a file
#   * Command-line options are introduced to enable different options to be passed to the commands
#   * Introducing variables, if tests, loops enables more complex program flow
#   * At some point pre- and postprocessing becomes too advanced for bash, at which point (parts of) the script should be ported to Python or other tools
# * Shell scripts are often used to glue more advanced scripts in Perl and Python

# %% [markdown]
# ## Remark
#
# * We use plain Bourne shell (`/bin/sh`) when special features of Bash (`/bin/bash`) are not needed
# * Most of our examples can in fact be run under Bourne shell (and of course also Bash)
# * In Mac OSX, the Bourne shell (`/bin/sh`) is just a link to Bash
#     (`/bin/bash`). In Ubuntu, the Bourne shell (`/bin/sh`) is a link to Dash, a
#     minimal, but much faster shell than bash.
# * On Windows bash is available through `cygwin` or the Linux-Subsystem in Windows 10.

# %% [markdown]
# ## More information
#
#   * `man bash`

# %%
man bash
# Out:
# BASH(1)                     General Commands Manual                    BASH(1)
#
# E
#        bash - GNU Bourne-Again SHell
#
# S
# h [options] [command_string | file]
#
# T
#        Bash is Copyright (C) 1989-2013 by the Free Software Foundation, Inc.
#
# N
# h-compatible  command language interpreter that executes
# h also incor‐
# h).
#
# h  is  intended  to  be a conformant implementation of the Shell and
#        Utilities portion  of  the  IEEE  POSIX  specification  (IEEE  Standard
# h can be configured to be POSIX-conformant by default.
#
# S
#        All  of  the  single-character shell options documented in the descrip‐
# t builtin command can be used as options when  the  shell
# h interprets the following options when it
#        is invoked:
#
# c option is present, then commands are read from  the
# g.  If there are argu‐
# g,  they  are  assigned  to  the
# 0.
# e.
# h act as if it had been invoked as a login shell (see
# N below).
# d
# L below).
# s option is present, or if no arguments remain after
#                  option processing, then commands are read from  the  standard
#                  input.   This  option  allows the positional parameters to be
#                  set when invoking an interactive shell.
# $ is  printed
#                  on  the standard output.  These are the strings that are sub‐
# C
# n option; no commands will be
#                  executed.
# ]
# n is one of the  shell  options  accepted  by  the
# S  below).   If
# O
# n is not supplied, the names and
# t are printed  on
# O, the
#                  output is displayed in a format that may be reused as input.
# - signals the end of options and disables  further  option
# - are treated as file‐
# -.
#
# h also  interprets  a  number  of  multi-character  options.   These
#        options  must  appear  on  the command line before the single-character
#        options to be recognized.
#
# r
#               Arrange for the debugger profile to be executed before the shell
#               starts.   Turns  on extended debugging mode (see the description
# t builtin below).
# s
# o  (por‐
#               table object) file format.
# s
# D.
# p Display  a  usage  message  on standard output and exit success‐
#               fully.
# e
# e
# e instead of the system  wide  initial‐
# c and the standard personal initial‐
# ‐
# N below).
#
# n
# l.
#
# g
# e library to read command lines when
#               the shell is interactive.
#
# e
# e  or
# e,
# h  reads  these
# N
#               below).
#
# c Do not read and execute  the  system  wide  initialization  file
# c
#               if the shell is interactive.  This option is on  by  default  if
# h.
#
# x
# h where the default operation differs
# e).  See
# O  below  for a reference to a document that details how
#               posix mode affects bash's behavior.
#
# d
# L below).
#
# e
# v.
#
# n
# h on the  stan‐
#               dard output and exit successfully.
#
# S
# c nor the
# s option has been supplied, the first argument is assumed  to  be  the
# h is invoked in this
# 0 is set to the name of the file, and the positional  parame‐
# h reads and executes com‐
# h's exit status is the exit  sta‐
#        tus  of  the  last  command executed in the script.  If no commands are
#        executed, the exit status is 0.  An attempt is first made to  open  the
#        file in the current directory, and, if no file is found, then the shell
# H for the script.
#
# N
# -,  or
# n option.
#
# e  shell  is one started without non-option arguments and
# c option whose standard input and error are both connected
# i
# h is interactive,  allowing
#        a shell script or a startup file to test this state.
#
# h executes its startup files.
# h  reports  an  error.
# ‐
# N section.
#
# h is invoked as an interactive login shell, or as a  non-inter‐
# n option, it first reads and executes com‐
# e, if that file exists.   After  reading
# e,
#        in that order, and reads and executes commands from the first one  that
# e option may be used when the
#        shell is started to inhibit this behavior.
#
# h reads and  executes  commands  from  the
# t, if it exists.
#
# h
# c,  if
# c option.
# h to read and  execute  commands
# c.
#
# h  is  started  non-interactively,  to run a shell script, for
# V in the environment, expands
#        its  value if it appears there, and uses the expanded value as the name
# h behaves as if the  following  com‐
#        mand were executed:
#               if [ -n "$BASH_ENV" ]; then . "$BASH_ENV"; fi
# H variable is not used to search for the file‐
#        name.
#
# h, it  tries  to  mimic  the  startup
# h as closely as possible, while
#        conforming to the POSIX standard as well.  When invoked as an  interac‐
# n option,
# e  and
# e  option may be used to
#        inhibit this behavior.  When invoked as an interactive shell  with  the
# V, expands its value if it is
#        defined, and uses the expanded value as the name of a file to read  and
# h does not attempt to read and exe‐
# e option has  no
# h does not
# h
# x mode after the startup files are read.
#
# x command line
#        option, it follows the POSIX standard for startup files.  In this mode,
# V variable and commands are read and
#        executed from the file whose name is  the  expanded  value.   No  other
#        startup files are read.
#
# h attempts to determine when it is being run with its standard input
#        connected to a network connection, as when executed by the remote shell
# h deter‐
#        mines it is being run in this fashion, it reads and  executes  commands
# c, if these files exist and are readable.
# c option may be used to
# e option may be used to force
# d generally invoke the
#        shell with those options or allow them to be specified.
#
#        If the shell is started with the effective user (group) id not equal to
# p option is not supplied, no startup
#        files are read, shell functions are not inherited from the environment,
# E  variables,  if  they
#        appear  in  the  environment, are ignored, and the effective user id is
# p option is supplied  at  invocation,
#        the  startup  behavior  is  the  same, but the effective user id is not
#        reset.
#
# S
#        The following definitions are used throughout the rest  of  this  docu‐
#        ment.
# k  A space or tab.
# d   A  sequence  of  characters  considered  as a single unit by the
# n.
# d consisting only of  alphanumeric  characters  and  under‐
#               scores,  and beginning with an alphabetic character or an under‐
# r.
# r
#               A character that, when unquoted, separates words.   One  of  the
#               following:
# b
# r
# n that performs a control function.  It is one of the fol‐
#               lowing symbols:
# >
#
# S
# s are words that have a special meaning to the shell.  The
#        following words are recognized as reserved when unquoted and either the
# R below) or  the  third
# r command:
#
# t
# ]
#
# R
# s
# d is a sequence of optional  variable  assignments  fol‐
# k-separated  words and redirections, and terminated by a
# r.  The first word specifies the command to be executed,
#        and  is  passed  as  argument  zero.  The remaining words are passed as
#        arguments to the invoked command.
#
# n  if
# n.
#
# s
# e  is  a sequence of one or more commands separated by one of
# &.  The format for a pipeline is:
#
# 2 ... ]
#
# d is connected via a pipe to the  standard
# 2.   This connection is performed before any redirec‐
# & is used,
# d's  standard  error, in addition to its standard output, is con‐
# 2's standard input through the pipe; it  is  shorthand
# |.   This  implicit redirection of the standard error to the
#        standard output is performed after any redirections  specified  by  the
#        command.
#
#        The return status of a pipeline is the exit status of the last command,
# l  is  enabled,  the
#        pipeline's  return  status is the value of the last (rightmost) command
#        to exit with a non-zero status, or zero if all commands  exit  success‐
# !  precedes a pipeline, the exit status of
#        that pipeline is the logical negation of the exit status  as  described
#        above.   The  shell waits for all commands in the pipeline to terminate
#        before returning a value.
#
# e reserved word precedes a pipeline, the elapsed as  well  as
#        user  and  system  time consumed by its execution are reported when the
# p option changes the output format  to  that
# e, it does not rec‐
# e as a reserved word if the next token  begins  with  a  `-'.
# T  variable  may be set to a format string that specifies
#        how the timing information should be displayed; see the description  of
# s below.
#
# e may be followed by a newline.  In
#        this case, the shell displays the total user and system  time  consumed
# T variable may be used to
#        specify the format of the time information.
#
#        Each command in a pipeline is executed as a separate process (i.e.,  in
#        a subshell).
#
# s
# t  is a sequence of one or more pipelines separated by one of the
# &, or
# >.
#
# ;
# &, which have equal precedence.
#
# t  instead  of  a
#        semicolon to delimit commands.
#
# &, the shell exe‐
# d in a subshell.  The shell does  not
#        wait  for  the command to finish, and the return status is 0.  Commands
# ; are executed sequentially; the shell  waits  for  each
#        command  to terminate in turn.  The return status is the exit status of
#        the last command executed.
#
#        AND and OR lists are sequences of one of more  pipelines  separated  by
# | control operators, respectively.  AND and OR lists are
#        executed with left associativity.  An AND list has the form
#
# 2
#
# 1 returns an  exit  status
#        of zero.
#
#        An OR list has the form
#
# 2
#
# 1 returns a non-zero exit
#        status.  The return status of AND and OR lists is the  exit  status  of
#        the last command executed in the list.
#
# s
# t in a
#        command's description may be separated from the rest of the command  by
#        one  or  more  newlines, and may be followed by a newline in place of a
#        semicolon.
#
# ‐
# T below).  Variable assignments and builtin com‐
#               mands that affect the  shell's  environment  do  not  remain  in
#               effect  after  the  command completes.  The return status is the
# t.
#
# t; }
# t
#               must  be  terminated with a newline or semicolon.  This is known
# d.  The return status is  the  exit  status  of
# } are
# s and must occur where a reserved word is permitted
#               to  be  recognized.   Since they do not cause a word break, they
# t  by  whitespace  or  another  shell
#               metacharacter.
#
# n))
# n  is  evaluated  according to the rules described
# N.  If the value of the  expres‐
#               sion  is  non-zero, the return status is 0; otherwise the return
# ".
#
# ]
#               Return a status of 0 or 1 depending on  the  evaluation  of  the
# n.  Expressions are composed of
# S.
#               Word  splitting  and pathname expansion are not performed on the
# ];  tilde  expansion,  parameter  and
#               variable  expansion, arithmetic expansion, command substitution,
#               process substitution, and quote removal are  performed.   Condi‐
# f must be unquoted to be recognized as
#               primaries.
#
# > operators sort  lexicographically
#               using the current locale.
#
# t builtin command (section SHELL BUILTIN
#        COMMANDS below) for the handling of parameters (i.e.   missing  parame‐
#        ters).
#
# = operators are used, the string to the right of the
#        operator is considered a pattern and matched  according  to  the  rules
# b shell option
# =.  If the shell option
# h  is  enabled,  the match is performed without regard to the
#        case of alphabetic characters.  The return value is  0  if  the  string
# =) the pattern, and 1 otherwise.  Any
#        part of the pattern may be quoted to force the  quoted  portion  to  be
#        matched as a string.
#
# ~, is available, with the same prece‐
# =.  When it is used, the string to the  right  of  the
#        operator  is  considered  an  extended  regular  expression and matched
# x(3)).  The return value  is  0  if  the  string
#        matches  the  pattern,  and  1 otherwise.  If the regular expression is
#        syntactically incorrect, the conditional expression's return  value  is
# h is enabled, the match is performed
#        without regard to the case of alphabetic characters.  Any part  of  the
#        pattern  may  be  quoted to force the quoted portion to be matched as a
#        string.  Bracket expressions in regular  expressions  must  be  treated
#        carefully,  since normal quoting characters lose their meanings between
#        brackets.  If the pattern is stored in a shell  variable,  quoting  the
#        variable expansion forces the entire pattern to be matched as a string.
#        Substrings matched by parenthesized subexpressions within  the  regular
# H.  The element
# H with index 0 is the portion of the string matching  the
# n is
# nth parenthesized subexpression.
#
#        Expressions may be combined using the following  operators,  listed  in
#        decreasing order of precedence:
#
# )
# n.  This may be used to
#                      override the normal precedence of operators.
# n
# n is false.
# 2
# 2 are true.
# 2
# 2 is true.
#
# 2 if the value
# 1  is  sufficient to determine the return value of
#               the entire conditional expression.
#
# e
# n is expanded, generating a list of
# e is set to each element of this list in
# d  is  omit‐
# t once for each positional
# S below).  The return status
#               is  the  exit  status of the last command that executes.  If the
# n results in an empty list, no
#               commands are executed, and the return status is 0.
#
# e
# 1 is evaluated according to
# N.   The
# 2 is then evaluated repeatedly until
# 2 evaluates to  a  non-zero
# 3 is
#               evaluated.  If any expression is omitted, it behaves  as  if  it
#               evaluates to 1.  The return value is the exit status of the last
# t that is executed, or false if any of the expres‐
#               sions is invalid.
#
# e
# n is expanded, generating a list of
#               items.  The set of expanded words is  printed  on  the  standard
# d is omitted,
# S  below).
# 3 prompt is then displayed and a line read from the stan‐
#               dard input.  If the line consists of a number  corresponding  to
# e is set to
#               that word.  If the line is empty, the words and prompt are  dis‐
#               played again.  If EOF is read, the command completes.  Any other
# e to be set to  null.   The  line  read  is
# t is executed after each
# k command is executed.  The exit status of
# t,
#               or zero if no commands were executed.
#
# c
# d, and tries to match it against
# n in turn, using the same matching rules as for path‐
# d  is
#               expanded  using  tilde  expansion, parameter and variable expan‐
#               sion, arithmetic  substitution,  command  substitution,  process
# n  examined  is
#               expanded using tilde expansion, parameter  and  variable  expan‐
#               sion, arithmetic substitution, command substitution, and process
# h is  enabled,  the
#               match  is  performed  without  regard  to the case of alphabetic
# t  is
# ; operator is used, no subsequent matches are
# & in  place  of
# t associated with
# ;  causes  the
#               shell  to  test  the next pattern list in the statement, if any,
# t on a successful match.  The exit
#               status is zero if no pattern matches.  Otherwise, it is the exit
# t.
#
# i
# n
# t is executed in
# n
# e
# t is executed, if present.  The exit status is the exit  sta‐
#               tus of the last command executed, or zero if no condition tested
#               true.
#
# e
# e
# 2 as  long
# 1 returns an exit status of
# e  command,
# 2 is executed as long as
# 1 returns a non-zero exit status.   The
# l commands is the exit status
# 2, or zero if none was exe‐
#               cuted.
#
# s
# c reserved word.  A
#        coprocess is executed asynchronously in a subshell, as if  the  command
# & control operator, with a two-way pipe
#        established between the executing shell and the coprocess.
#
#        The format for a coprocess is:
#
# s]
#
# E  is  not  supplied,  the
# ‐
# d (see above); otherwise, it is interpreted as the first word
#        of  the simple command.  When the coprocess is executed, the shell cre‐
# E in the context  of
# d is connected via a
#        pipe to a file  descriptor  in  the  executing  shell,  and  that  file
# d is
#        connected via a pipe to a file descriptor in the executing  shell,  and
# E[1].  This pipe is established
# N
#        below).   The  file  descriptors  can be utilized as arguments to shell
#        commands and redirections using standard  word  expansions.   The  file
#        descriptors  are  not  available  in  subshells.  The process ID of the
#        shell spawned to execute the coprocess is available as the value of the
# t builtin command may be used to wait for
#        the coprocess to terminate.
#
# c
#        command  always  returns  success.  The return status of a coprocess is
# d.
#
# s
#        A shell function is an object that is called like a simple command  and
#        executes  a  compound  command with a new set of positional parameters.
#        Shell functions are declared as follows:
#
# n]
# n]
# n
# n reserved word is supplied, the
# y of the function is the  com‐
# s above).
# t of commands between { and },  but
# ‐
# e is specified as the name
# e may not be the
# s.   Any  redirections
# N below) specified when a function is defined are
#               performed when the function is executed.  The exit status  of  a
#               function  definition  is  zero unless a syntax error occurs or a
#               readonly function with the same name already exists.  When  exe‐
#               cuted,  the  exit status of a function is the exit status of the
# S below.)
#
# S
# ‐
# L
# # causes that  word  and
#        all  remaining  characters  on that line to be ignored.  An interactive
# s option enabled  does  not  allow
# s option is on by default in interac‐
#        tive shells.
#
# G
# g is used to remove the special meaning of certain characters  or
#        words  to  the shell.  Quoting can be used to disable special treatment
#        for special characters, to prevent reserved words from being recognized
#        as such, and to prevent parameter expansion.
#
# S has special
#        meaning to the shell and must be quoted if it is to represent itself.
#
# ‐
# !, must
#        be quoted to prevent history expansion.
#
# r,  single
#        quotes, and double quotes.
#
# r.  It preserves the
#        literal value of the next character that follows, with the exception of
# \<newline>  pair  appears, and the backslash is not
# \<newline> is treated as a line  continuation  (that
#        is, it is removed from the input stream and effectively ignored).
#
#        Enclosing  characters  in  single quotes preserves the literal value of
#        each character within the quotes.  A single quote may not occur between
#        single quotes, even when preceded by a backslash.
#
#        Enclosing  characters  in  double quotes preserves the literal value of
# \,  and,
# ` retain
#        their special meaning within double quotes.  The backslash retains  its
#        special  meaning only when followed by one of the following characters:
# >.  A double quote may be quoted  within  double
#        quotes by preceding it with a backslash.  If enabled, history expansion
# !  appearing in double  quotes  is  escaped
# !  is not removed.
#
# @ have special meaning when in double
# S below).
#
# g' are treated specially.  The word expands to
# g,  with backslash-escaped characters replaced as specified by the
#        ANSI C standard.  Backslash escape sequences, if present,  are  decoded
#        as follows:
# a     alert (bell)
# b     backspace
# e
# E     an escape character
# f     form feed
# n     new line
# r     carriage return
# t     horizontal tab
# v     vertical tab
# \     backslash
# '     single quote
# "     double quote
# n   the  eight-bit  character  whose value is the octal value
# n (one to three digits)
# H   the eight-bit character whose value  is  the  hexadecimal
# H (one or two hex digits)
# H the  Unicode (ISO/IEC 10646) character whose value is the
# H (one to four hex digits)
# H
#                      the Unicode (ISO/IEC 10646) character whose value is  the
# H (one to eight hex digits)
# x character
#
#        The  expanded  result  is  single-quoted, as if the dollar sign had not
#        been present.
#
# g") will cause
#        the  string  to  be translated according to the current locale.  If the
# X, the  dollar  sign  is  ignored.   If  the
#        string is translated and replaced, the replacement is double-quoted.
#
# S
# e, a num‐
# ‐
# e.  A variable has a
# s.  Attributes are assigned  using  the
# S).
#
#        A parameter is set if it has been assigned a value.  The null string is
#        a valid value.  Once a variable is set, it may be unset only  by  using
# S below).
#
# e may be assigned to by a statement of the form
#
# e]
#
# e  is not given, the variable is assigned the null string.  All
# s undergo tilde expansion, parameter and variable expansion,  com‐
# ‐
# e
#        is evaluated as an arithmetic expression even if the $((...)) expansion
# n below).  Word  splitting  is  not
# l
# s.  Pathname expansion is not  performed.   Assignment  state‐
# t,
# e,
#        these  builtins  may appear in a command after one or more instances of
# d builtin and retain these assignment statement properties.
#
#        In the context where an assignment statement is assigning a value to  a
#        shell variable or array index, the += operator can be used to append to
#        or add to the variable's previous value.  When += is applied to a vari‐
# e is evaluated
#        as an arithmetic expression and added to the variable's current  value,
#        which is also evaluated.  When += is applied to an array variable using
# s below), the  variable's  value  is  not
#        unset (as it is when using =), and new values are appended to the array
#        beginning at one greater than the array's maximum  index  (for  indexed
#        arrays) or added as additional key-value pairs in an associative array.
# e  is  expanded  and
#        appended to the variable's value.
#
# n option to
# e
# f, or a reference to another vari‐
#        able.  This allows variables to be  manipulated  indirectly.   Whenever
#        the  nameref  variable  is  referenced or assigned to, the operation is
#        actually performed on the variable specified by the nameref  variable's
#        value.  A nameref is commonly used within shell functions to refer to a
#        variable whose name is passed as an  argument  to  the  function.   For
#        instance, if a variable name is passed to a shell function as its first
#        argument, running
#               declare -n ref=$1
# f whose value  is  the
#        variable name passed as the first argument.  References and assignments
# f are treated as references and assignments to the variable  whose
# r loop has the
#        nameref attribute, the list of words can be a list of shell  variables,
#        and  a name reference will be established for each word in the list, in
#        turn, when the loop is executed.  Array variables cannot be  given  the
# n attribute.  However, nameref variables can reference array variables
# n
# t is executed with the
#        name of a nameref variable as an argument, the variable  referenced  by
#        the nameref variable will be unset.
#
# s
# r  is a parameter denoted by one or more digits,
#        other than the single digit 0.  Positional parameters are assigned from
#        the  shell's  arguments when it is invoked, and may be reassigned using
# t builtin command.  Positional parameters may not be assigned  to
#        with  assignment statements.  The positional parameters are temporarily
# S below).
#
#        When a positional parameter consisting of more than a single  digit  is
# N below).
#
# s
#        The  shell  treats  several parameters specially.  These parameters may
#        only be referenced; assignment to them is not allowed.
# *      Expands to the positional parameters, starting from  one.   When
#               the  expansion  is  not  within  double  quotes, each positional
#               parameter expands to a separate word.  In contexts where  it  is
#               performed, those words are subject to further word splitting and
#               pathname expansion.  When the  expansion  occurs  within  double
#               quotes,  it  expands  to  a  single  word with the value of each
# S  special
# c
# S
# S is
#               null, the parameters are joined without intervening separators.
# @      Expands to the positional parameters, starting from  one.   When
#               the  expansion  occurs  within  double  quotes,  each  parameter
# 1"
# 2"  ...   If the double-quoted expansion occurs within a word,
#               the expansion of the first parameter is joined with  the  begin‐
#               ning  part  of  the original word, and the expansion of the last
#               parameter is joined with the last part  of  the  original  word.
# @ expand to
#               nothing (i.e., they are removed).
# #      Expands to the number of positional parameters in decimal.
# ?      Expands to the exit status of the most recently  executed  fore‐
#               ground pipeline.
# -      Expands  to  the  current option flags as specified upon invoca‐
# t builtin command, or  those  set  by  the  shell
# i option).
# $      Expands  to  the  process ID of the shell.  In a () subshell, it
#               expands to the process ID of the current  shell,  not  the  sub‐
#               shell.
# !      Expands  to  the process ID of the job most recently placed into
#               the background, whether executed as an asynchronous  command  or
# L below).
# 0      Expands  to  the name of the shell or shell script.  This is set
# h is invoked with a file of com‐
# h is started
# 0 is set to the first  argument  after
#               the  string to be executed, if one is present.  Otherwise, it is
# h, as  given  by  argument
#               zero.
# _      At  shell  startup,  set to the absolute pathname used to invoke
#               the shell or shell script being executed as passed in the  envi‐
#               ronment  or  argument  list.   Subsequently, expands to the last
#               argument to the previous command, after expansion.  Also set  to
#               the  full  pathname  used  to  invoke  each command executed and
#               placed in the environment exported to that command.  When check‐
#               ing  mail,  this  parameter holds the name of the mail file cur‐
#               rently being checked.
#
# s
#        The following variables are set by the shell:
#
# H   Expands to the full filename used to  invoke  this  instance  of
# h.
# S
#               A  colon-separated  list of enabled shell options.  Each word in
# t
# S below).  The options
# t.   If
# h starts up, each
#               shell option in the list will  be  enabled  before  reading  any
#               startup files.  This variable is read-only.
# D
# h process.  This
# $ under certain circumstances, such  as  subshells
# h to be re-initialized.
# S
#               An  associative  array  variable whose members correspond to the
# s  builtin.
#               Elements added to this array appear in the alias list; unsetting
#               array elements cause aliases to be removed from the alias list.
# C
#               An array variable whose values are the number of  parameters  in
# h execution call stack.  The number
#               of parameters to  the  current  subroutine  (shell  function  or
# e) is at the top of the stack.
#               When a subroutine is executed, the number of  parameters  passed
# C only when in
# g
# t builtin below)
# V
#               An  array  variable containing all of the parameters in the cur‐
# h execution call stack.  The final parameter of the last
#               subroutine  call is at the top of the stack; the first parameter
#               of the initial call is at the bottom.  When a subroutine is exe‐
# V.  The
# V only when in extended debugging  mode  (see
# t builtin
#               below)
# S
#               An associative array variable whose members  correspond  to  the
# h
#               builtin.  Elements added to this array appear in the hash table;
#               unsetting  array  elements cause commands to be removed from the
#               hash table.
# D
#               The command currently being executed or about  to  be  executed,
#               unless the shell is executing a command as the result of a trap,
#               in which case it is the command executing at  the  time  of  the
#               trap.
# G
# c invocation option.
# O
#               An  array  variable whose members are the line numbers in source
# E  was  invoked.
# }  is  the  line  number  in  the  source  file
# }  was  called  (or
# }  if  referenced  within another shell func‐
# O to obtain the current line number.
# H
# ~  binary
# [ conditional command.  The element with index
#               0 is the portion of  the  string  matching  the  entire  regular
# n is the portion of the
# nth parenthesized subexpression.  This vari‐
#               able is read-only.
# E
#               An  array  variable whose members are the source filenames where
# E  array
# } is
# }   and   called   from
# }.
# L
#               Incremented  by one within each subshell or subshell environment
#               when the shell begins executing in that environment.   The  ini‐
#               tial value is 0.
# O
#               A readonly array variable whose members hold version information
# h.  The values  assigned  to  the  array
#               members are as follows:
# e).
# n).
# ]        The patch level.
# ]        The build version.
# 1).
# E.
# N
#               Expands  to  a string describing the version of this instance of
# h.
# D
# } of the word containing  the  current
#               cursor position.  This variable is available only in shell func‐
#               tions invoked by the  programmable  completion  facilities  (see
# n below).
# Y
#               The key (or final key of a key sequence) used to invoke the cur‐
#               rent completion function.
# E
#               The current command line.  This variable is  available  only  in
#               shell  functions  and  external commands invoked by the program‐
# n below).
# T
#               The index of the current cursor position relative to the  begin‐
#               ning  of the current command.  If the current cursor position is
#               at the end of the current command, the value of this variable is
# }.   This  variable  is available only in
#               shell functions and external commands invoked  by  the  program‐
# n below).
# E
#               Set  to an integer value corresponding to the type of completion
# B,
# ?, for listing completions after succes‐
# !, for listing alternatives on partial  word  comple‐
# @,  to list completions if the word is not unmodified, or
# %, for menu completion.  This  variable  is  available  only  in
#               shell  functions  and  external commands invoked by the program‐
# n below).
# S
# e library treats  as  word
# S
#               is unset, it loses its special properties, even if it is  subse‐
#               quently reset.
# S
# s below) consisting of the individ‐
#               ual words in the current command line.  The line is  split  into
# S as
#               described above.  This variable is available only in shell func‐
#               tions  invoked  by  the  programmable completion facilities (see
# n below).
# s below) created to  hold  the  file
#               descriptors  for  output  from and input to an unnamed coprocess
# s above).
# K
# s below) containing the current con‐
#               tents  of  the directory stack.  Directories appear in the stack
# s builtin.   Assigning
#               to members of this array variable may be used to modify directo‐
# d builtins  must
#               be used to add and remove directories.  Assignment to this vari‐
# K  is
#               unset,  it  loses  its  special properties, even if it is subse‐
#               quently reset.
# D   Expands to the effective user ID of the current  user,  initial‐
#               ized at shell startup.  This variable is readonly.
# E
#               An  array  variable  containing the names of all shell functions
#               currently in the execution call stack.  The element with index 0
#               is the name of any currently-executing shell function.  The bot‐
#               tom-most element (the one with the  highest  index)  is  "main".
#               This  variable  exists  only when a shell function is executing.
# E have no effect and return an error  sta‐
# E  is  unset, it loses its special properties,
#               even if it is subsequently reset.
#
# E.
# E  has  corresponding  elements  in
# E to describe  the  call  stack.   For
# }    was   called   from   the   file
# }.   The
# r builtin displays the current call stack using this infor‐
#               mation.
# S An array variable containing the list of  groups  of  which  the
# S have no effect
# S is unset,  it  loses  its
#               special properties, even if it is subsequently reset.
# D
#               The history number, or index in the history list, of the current
# D is unset, it loses its special  properties,
#               even if it is subsequently reset.
# E
#               Automatically set to the name of the current host.
# E
#               Automatically  set  to a string that uniquely describes the type
# h is executing.  The default  is  system-
#               dependent.
# O Each  time this parameter is referenced, the shell substitutes a
#               decimal number representing the current sequential  line  number
#               (starting  with  1)  within a script or function.  When not in a
#               script or function, the value substituted is not  guaranteed  to
# O is unset, it loses its special proper‐
#               ties, even if it is subsequently reset.
# E
#               Automatically set to a string that fully  describes  the  system
# ‐
# m format.  The default is system-dependent.
# E
# s below) created to  hold  the  text
# e builtin when no variable name is supplied.
# d command.
# s
# S below).
# s
# S below).
# E Automatically  set to a string that describes the operating sys‐
# h is executing.  The  default  is  system-depen‐
#               dent.
# S
# s below) containing a list of exit
#               status values from the processes in  the  most-recently-executed
#               foreground pipeline (which may contain only a single command).
# D   The  process  ID  of the shell's parent.  This variable is read‐
#               only.
# d command.
# M Each time this parameter is referenced, a random integer between
#               0 and 32767 is generated.  The sequence of random numbers may be
# M is unset,
#               it  loses  its  special  properties,  even if it is subsequently
#               reset.
# E
# e line buffer, for use with "bind -x"
# S below).
# T
# e line buffer,
# S below).
# d builtin  command  when
#               no arguments are supplied.
# S
#               Each  time  this  parameter is referenced, the number of seconds
#               since shell invocation is returned.  If a value is  assigned  to
# S,  the  value  returned upon subsequent references is the
#               number of seconds since the assignment plus the value  assigned.
# S is unset, it loses its special properties, even if it
#               is subsequently reset.
# S
#               A colon-separated list of enabled shell options.  Each  word  in
# t
# S below).  The options
# o.  If
# h  starts  up,  each
#               shell  option  in  the  list  will be enabled before reading any
#               startup files.  This variable is read-only.
# h is started.
# D    Expands to the user ID of the current user, initialized at shell
#               startup.  This variable is readonly.
#
# h
#        assigns a default value to a variable; these cases are noted below.
#
# T
#               The value is used to set the shell's compatibility  level.   See
# N
# S for a description of the various  compatibility  levels
#               and  their  effects.   The  value may be a decimal number (e.g.,
#               4.2) or an integer (e.g., 42) corresponding to the desired  com‐
# T is unset or set to the empty
#               string, the compatibility level is set to the  default  for  the
# T is set to a value that is not
#               one of the valid compatibility levels, the shell prints an error
#               message  and sets the compatibility level to the default for the
#               current version.  The valid compatibility levels  correspond  to
# t  builtin
# 2 means that 4.2 and 42 are
#               valid values).  The current version is also a valid value.
# V
# h is executing a shell script,
#               its value is interpreted as a filename  containing  commands  to
# V is
#               subjected to  parameter  expansion,  command  substitution,  and
#               arithmetic  expansion  before  being  interpreted as a filename.
# H is not used to search for the resultant filename.
# D
#               If set to an integer corresponding to a valid  file  descriptor,
# x is
#               enabled to that file descriptor.  The file descriptor is  closed
# D is unset or assigned a new value.  Unsetting
# D or assigning it the empty string causes the  trace
#               output  to  be  sent  to  the standard error.  Note that setting
# D to 2 (the standard error file descriptor) and then
#               unsetting it will result in the standard error being closed.
# d command.  This is a colon-separated
#               list of directories in which the  shell  looks  for  destination
# d  command.  A sample value is
#               ".:~:/usr".
# X
#               Set the number of exited child status values for  the  shell  to
#               remember.   Bash will not allow this value to be decreased below
#               a POSIX-mandated minimum, and there is  a  maximum  value  (cur‐
#               rently  8192)  that  this  may not exceed.  The minimum value is
#               system-dependent.
# S
# t compound command to  determine  the  terminal
#               width  when  printing selection lists.  Automatically set if the
# e option is enabled or in an interactive  shell  upon
# H.
# Y
# h reads the possible completions
#               generated by a shell function invoked by the  programmable  com‐
# n  below).  Each
#               array element contains one possible completion.
# h finds this variable in the environment  when  the  shell
#               starts  with  value "t", it assumes that the shell is running in
#               an Emacs shell buffer and disables line editing.
# V; used when the shell  is  invoked  in  POSIX
#               mode.
# c builtin command.
# E
#               A  colon-separated  list  of  suffixes to ignore when performing
# E below).  A filename whose suf‐
# E is excluded from the
#               list of matched filenames.  A sample value is ".o:~" (Quoting is
#               needed  when  assigning a value to this variable, which contains
#               tildes).
# T
#               If set to a numeric value greater  than  0,  defines  a  maximum
#               function  nesting  level.  Function invocations that exceed this
#               nesting level will cause the current command to abort.
# E
#               A colon-separated list of patterns defining the set of filenames
#               to be ignored by pathname expansion.  If a filename matched by a
#               pathname expansion pattern also matches one of the  patterns  in
# E, it is removed from the list of matches.
# L
#               A  colon-separated  list  of values controlling how commands are
#               saved on the history list.   If  the  list  of  values  includes
# e character are not
# s  causes  lines
#               matching the previous history entry to not be saved.  A value of
# s.  A value
# s causes all previous lines matching the current line
#               to be removed from the history list before that line  is  saved.
# L is
#               unset, or does not include a valid value, all lines read by  the
#               shell parser are saved on the history list, subject to the value
# E.  The second and subsequent lines of a  multi-line
#               compound  command  are  not tested, and are added to the history
# L.
# E
# ‐
# y.  If unset,
#               the command history is not saved when a shell exits.
# E
#               The maximum number of lines contained in the history file.  When
#               this  variable  is  assigned  a value, the history file is trun‐
#               cated, if necessary, to contain no  more  than  that  number  of
#               lines  by removing the oldest entries.  The history file is also
#               truncated to this size after writing it when a shell exits.   If
#               the  value  is  0,  the  history file is truncated to zero size.
#               Non-numeric values and numeric values  less  than  zero  inhibit
#               truncation.   The  shell  sets the default value to the value of
# E after reading any startup files.
# E
#               A colon-separated list of patterns used to decide which  command
#               lines  should  be  saved  on  the history list.  Each pattern is
#               anchored at the beginning of the line and must  match  the  com‐
# *'  is  appended).  Each pattern is
# ‐
# L  are  applied.   In  addition  to  the normal shell pattern
# &'
#               may  be  escaped  using  a  backslash;  the backslash is removed
#               before attempting a match.  The second and subsequent lines of a
#               multi-line compound command are not tested, and are added to the
# E.
# E
#               The number of commands to remember in the command  history  (see
# Y  below).   If  the value is 0, commands are not saved in
#               the history list.  Numeric values less than zero result in every
#               command  being  saved  on  the history list (there is no limit).
#               The shell sets the  default  value  to  500  after  reading  any
#               startup files.
# T
#               If  this  variable  is  set and not null, its value is used as a
# e(3) to print the time stamp associated
# y builtin.  If
#               this variable is set, time stamps are  written  to  the  history
#               file  so they may be preserved across shell sessions.  This uses
#               the history comment character  to  distinguish  timestamps  from
#               other history lines.
# E   The home directory of the current user; the default argument for
# d builtin command.  The value of this variable is also used
#               when performing tilde expansion.
# E
# s
#               that should be read when the shell needs to complete a hostname.
#               The  list  of possible hostname completions may be changed while
#               the shell is running;  the  next  time  hostname  completion  is
# h adds the contents of
# E is set, but  has
# h attempts to
# s to obtain the list of possible hostname  comple‐
# E is unset, the hostname list is cleared.
# r  that is used for word splitting
# d
#               builtin  command.   The  default  value  is  ``<space><tab><new‐
#               line>''.
# F
# F
#               character as the sole input.  If set, the value is the number of
# F characters which must  be  typed  as  the  first
# h exits.  If the variable
#               exists but does not have a numeric value, or has no  value,  the
# F signifies the
#               end of input to the shell.
# C
# e  startup  file,  overriding  the
# E below).
# G   Used  to  determine  the  locale  category  for any category not
# _.
# _
#               variable specifying a locale category.
# E
#               This  variable  determines the collation order used when sorting
#               the results of pathname expansion, and determines  the  behavior
#               of   range   expressions,  equivalence  classes,  and  collating
#               sequences within pathname expansion and pattern matching.
# E
#               This variable determines the interpretation  of  characters  and
#               the  behavior of character classes within pathname expansion and
#               pattern matching.
# S
#               This variable determines the locale used  to  translate  double-
# $.
# C
#               This  variable  determines  the  locale category used for number
#               formatting.
# t compound  command  to  determine  the  column
#               length  for  printing selection lists.  Automatically set if the
# e option is enabled or in an interactive  shell  upon
# H.
# L   If  this  parameter  is  set to a file or directory name and the
# h  informs  the  user  of  the
#               arrival  of  mail in the specified file or Maildir-format direc‐
#               tory.
# K
# h  checks  for  mail.   The
#               default  is  60 seconds.  When it is time to check for mail, the
#               shell does so before displaying the  primary  prompt.   If  this
#               variable  is  unset,  or  set  to  a  value that is not a number
#               greater than or equal to zero, the shell disables mail checking.
# H
#               A colon-separated list of filenames to be checked for mail.  The
#               message to be printed when mail arrives in a particular file may
#               be specified by separating the filename from the message with  a
# _ expands to the
#               name of the current mailfile.  Example:
# H='/var/mail/bfox?"You  have  mail":~/shell-mail?"$_  has
#               mail!"'
# h  supplies  a default value for this variable, but the loca‐
#               tion of the user mail files that it  uses  is  system  dependent
# R).
# h displays error messages generated by
# S  below).
# R  is  initialized to 1 each time the shell is invoked or a
#               shell script is executed.
# H   The search path for commands.  It is a colon-separated  list  of
# D
# N below).  A zero-length (null) directory  name  in  the
# H indicates the current directory.  A null directory
#               name may appear as two adjacent colons,  or  as  an  initial  or
#               trailing  colon.   The  default path is system-dependent, and is
# h.  A common  value  is
#               ``/usr/local/bin:/usr/local/sbin:/usr/bin:/usr/sbin:/bin:
#               /sbin''.
# T
# h  starts,  the
# e before reading the startup files, as if
# x invocation option had been supplied.  If it  is  set
# e, as if the
# x had been executed.
# D
#               If set, the value is executed as a command prior to issuing each
#               primary prompt.
# M
#               If  set  to a number greater than zero, the value is used as the
#               number of trailing directory components to retain when expanding
# G below).
#               Characters removed are replaced with an ellipsis.
# G  below)
#               and  used  as  the  primary prompt string.  The default value is
# $ ''.
# 1 and used  as
# > ''.
# t
# R above).
# 1  and  the
# h displays during an
# 4 is replicated  mul‐
#               tiple  times, as necessary, to indicate multiple levels of indi‐
# + ''.
# L  The full pathname to the shell is kept in this environment vari‐
# h assigns to
#               it the full pathname of the current user's login shell.
# T
#               The value of this parameter is used as a format string  specify‐
#               ing  how  the timing information for pipelines prefixed with the
# % character  intro‐
#               duces  an  escape  sequence  that is expanded to a time value or
#               other information.  The escape sequences and their meanings  are
#               as follows; the braces denote optional portions.
# %.
# R  The elapsed time in seconds.
# U  The number of CPU seconds spent in user mode.
# S  The number of CPU seconds spent in system mode.
# P        The CPU percentage, computed as (%U + %S) / %R.
#
# n, the number
#               of fractional digits after a decimal point.  A value of 0 causes
#               no decimal point or fraction to be output.  At most three places
# p  greater
# p is not specified, the value 3 is
#               used.
#
# l specifies a longer format, including minutes,  of
# p determines whether or not
#               the fraction is included.
#
# h acts as if it  had  the  value
# '.   If  the value is null,
#               no timing information is displayed.  A trailing newline is added
#               when the format string is displayed.
# T is treated as the
# t command termi‐
# T seconds when input is
#               coming from a terminal.  In an interactive shell, the  value  is
#               interpreted as the number of seconds to wait for a line of input
# h terminates after waiting
#               for  that number of seconds if a complete line of input does not
#               arrive.
# h uses its value as the name of a directory in  which
# ...
# /,
#                       only directories and subdirectories match.
# t
#                       If set, shell error messages are written in the standard
#                       GNU error message format.
# d
#                       If  set,  the history list is appended to the file named
# E  variable  when  the  shell
#                       exits, rather than overwriting the file.
# t
# e is being used, a user is given the
#                       opportunity to re-edit a failed history substitution.
# y
# e is being used, the results of  his‐
#                       tory  substitution  are  not  immediately  passed to the
#                       shell parser.  Instead, the  resulting  line  is  loaded
# e editing buffer, allowing further modi‐
#                       fication.
# e
# h will attempt to
# @
# E
#                       above).  This is enabled by default.
# t
# P to all jobs when an inter‐
#                       active login shell exits.
# s
# # to cause that word
#                       and  all remaining characters on that line to be ignored
# S  above).   This
#                       option is enabled by default.
# e
#                       If  set,  and  job control is not active, the shell runs
#                       the last command of a pipeline not executed in the back‐
#                       ground in the current shell environment.
# t option is enabled, multi-line
#                       commands are saved to the history with embedded newlines
#                       rather than using semicolon separators where possible.
# l
#                       The  shell  sets this option if it is started as a login
# N above).   The  value  may  not  be
#                       changed.
# n
# h is checking for mail has
#                       been accessed since the last time it  was  checked,  the
# e has been read'' is dis‐
#                       played.
# n
# h  will  not
# H for possible completions when
#                       completion is attempted on an empty line.
# b
# h matches  filenames  in  a  case-insensitive
# e
# n above).
# h
# h  matches  patterns  in  a  case-insensitive
# e or
# [ conditional commands.
# b
# h allows patterns which match no  files  (see
# n  above)  to expand to a null string,
#                       rather than themselves.
# p
# ‐
# n above) are enabled.  This option is
#                       enabled by default.
# s
#                       If set, prompt strings undergo parameter expansion, com‐
#                       mand   substitution,  arithmetic  expansion,  and  quote
# G
#                       above.  This option is enabled by default.
# l
#                       The   shell  sets  this  option  if  it  is  started  in
# L below).  The value
#                       may  not be changed.  This is not reset when the startup
#                       files are executed, allowing the startup files  to  dis‐
#                       cover whether or not a shell is restricted.
# e
# t builtin prints an error message when
#                       the shift count exceeds the number of positional parame‐
#                       ters.
# h
# H to
#                       find the directory containing the file  supplied  as  an
#                       argument.  This option is enabled by default.
# o
# o  builtin  expands  backslash-escape
#                       sequences by default.
#
# f]
# T
# f option can be
#               used to override this and force the suspension.  The return sta‐
# f is not sup‐
#               plied, or if job control is not enabled.
#
# r
# ]
#               Return a status of 0 (true) or 1 (false) depending on the evalu‐
# r.  Each operator and op‐
#               erand must be a separate argument.  Expressions are composed  of
# S.
# t does not accept any options, nor does it accept and  ignore
# - as signifying the end of options.
#
#               Expressions  may  be  combined  using  the  following operators,
#               listed  in  decreasing  order  of  precedence.   The  evaluation
#               depends  on the number of arguments; see below.  Operator prece‐
#               dence is used when there are five or more arguments.
# r is false.
# )
# r.  This may be used to  override
#                      the normal precedence of operators.
# 2
# 2 are true.
# 2
# 2 is true.
#
# [ evaluate conditional expressions using a set of rules
#               based on the number of arguments.
#
#               0 arguments
#                      The expression is false.
#               1 argument
#                      The expression is true if and only if the argument is not
#                      null.
#               2 arguments
# !, the expression is true if and
#                      only if the second argument is null.  If the first  argu‐
#                      ment  is  one  of  the unary conditional operators listed
# S,  the  expression  is
#                      true if the unary test is true.  If the first argument is
#                      not a valid unary conditional operator, the expression is
#                      false.
#               3 arguments
#                      The following conditions are applied in the order listed.
#                      If the second argument is one of the  binary  conditional
# S, the
#                      result of the expression is the result of the binary test
# a
# o operators are  considered  binary  operators  when
# !,
#                      the value is the negation of the two-argument test  using
#                      the second and third arguments.  If the first argument is
# ), the result
#                      is  the one-argument test of the second argument.  Other‐
#                      wise, the expression is false.
#               4 arguments
# !, the result is the negation of
#                      the  three-argument  expression composed of the remaining
#                      arguments.  Otherwise, the expression is parsed and eval‐
#                      uated  according  to  precedence  using  the rules listed
#                      above.
#               5 or more arguments
#                      The expression  is  parsed  and  evaluated  according  to
#                      precedence using the rules listed above.
#
# > operators sort lexico‐
#               graphically using ASCII ordering.
#
# s  Print the accumulated user and system times for  the  shell  and
#               for processes run from the shell.  The return status is 0.
#
# c ...]
# g  is  to  be  read  and executed when the shell
# g is absent (and  there  is  a
# -,  each  specified signal is reset to its
#               original disposition (the value it  had  upon  entrance  to  the
# g is the null string the signal specified by each
# c is ignored by the shell and by the commands it  invokes.
# p has been supplied, then the trap
# c  are  displayed.   If  no
# p prints the
# l  option
#               causes  the shell to print a list of signal names and their cor‐
# c  is  either  a  signal  name
# h>,  or  a signal number.  Signal names are
# G prefix is optional.
#
# g  is  executed  on  exit
# g is exe‐
# e  command,
# r command, and before the
# R
# g option to the
# G trap.  If a
# g is executed each time a shell
# e builtins fin‐
#               ishes executing.
#
# g is executed whenever a a
#               pipeline (which may consist of a single simple command), a list,
#               or a compound command returns a non-zero exit status, subject to
# R trap is not executed  if  the
#               failed command is part of the command list immediately following
# f  statement,
# | list except the command
# |, any command in a pipeline but  the
#               last,  or  if the command's return value is being inverted using
# e)
#               option.
#
#               Signals  ignored  upon  entry  to the shell cannot be trapped or
#               reset.  Trapped signals that are not being ignored are reset  to
#               their original values in a subshell or subshell environment when
# c  is
# p returns true.
#
# e ...]
# e would be interpreted if
# e prints a
# n, or
# e  is  an  alias,  shell  reserved  word,  function,
# e is not found,
#               then nothing  is  printed,  and  an  exit  status  of  false  is
# e either returns the
# e were speci‐
#               fied as a command name, or nothing if ``type -t name'' would not
# e,
# e.  If a command is
# P print the hashed value, which is not necessar‐
# a option is
# e prints all of the places that contain  an  executable
# e.  This includes aliases and functions, if and only if
# p option is not also used.  The table of hashed commands is
# f option suppresses shell
# e returns true
#               if all of the arguments are found, false if any are not found.
#
# t]]
#               Provides  control  over the resources available to the shell and
#               to processes started by it, on systems that allow such  control.
# S options specify that the hard or soft limit is set
#               for the given resource.  A hard limit cannot be increased  by  a
#               non-root  user  once it is set; a soft limit may be increased up
# S is  speci‐
# t
#               can be a number in the unit specified for the resource or one of
# d, which stand for the
#               current hard limit,  the  current  soft  limit,  and  no  limit,
# t  is  omitted, the current value of the
# H  option  is
#               given.  When more than one resource is specified, the limit name
#               and unit are printed before the value.  Other options are inter‐
#               preted as follows:
# a     All current limits are reported
# b     The maximum socket buffer size
# c     The maximum size of core files created
# d     The maximum size of a process's data segment
# e     The maximum scheduling priority ("nice")
# f     The  maximum  size  of files written by the shell and its
#                      children
# i     The maximum number of pending signals
# l     The maximum size that may be locked into memory
# m     The maximum resident set size (many systems do not  honor
#                      this limit)
# n     The maximum number of open file descriptors (most systems
#                      do not allow this value to be set)
# p     The pipe size in 512-byte blocks (this may not be set)
# q     The maximum number of bytes in POSIX message queues
# r     The maximum real-time scheduling priority
# s     The maximum stack size
# t     The maximum amount of cpu time in seconds
# u     The maximum number of processes  available  to  a  single
#                      user
# v     The  maximum  amount  of  virtual memory available to the
#                      shell and, on some systems, to its children
# x     The maximum number of file locks
# T     The maximum number of threads
#
# t  is  the
#               new  value  of  the  specified resource.  If no option is given,
# f is assumed.  Values are in 1024-byte increments,  except
# p, which is in units of 512-byte
# u, which are unscaled values.   The
#               return  status is 0 unless an invalid option or argument is sup‐
#               plied, or an error occurs while setting a new limit.
#
# e]
# e begins with
#               a  digit,  it is interpreted as an octal number; otherwise it is
#               interpreted as a symbolic mode mask similar to that accepted  by
# e is omitted, the current value of the mask is
# S option causes the mask to be  printed  in  sym‐
# p
# e is omitted, the output is in a form
#               that may be reused as input.  The return status is 0 if the mode
# e  argument  was  supplied,
#               and false otherwise.
#
# e ...]
# a is
#               supplied, all alias definitions are removed.  The  return  value
# e is not a defined alias.
#
# e ...]
# e,  remove the corresponding variable or function.
# e refers to a shell variable,
#               and  that  variable  is removed.  Read-only variables may not be
# e refers to  a  shell  func‐
# n option
# f  attribute,
# n
# f option is supplied.  If no  options  are
# e refers to a variable; if there is no vari‐
#               able by that name, any function with that name is  unset.   Each
#               unset  variable  or  function  is  removed  from the environment
# ‐
# K are
#               unset, they lose their special properties, even if they are sub‐
# e is read‐
#               only.
#
# .]
#               Wait for each specified child process and return its termination
# n may be a process ID or a job specification; if a
#               job spec is given, all processes  in  that  job's  pipeline  are
# n is not given, all currently active child pro‐
# n
# t  waits  for any job to terminate and
# n specifies a non-existent  process
#               or  job, the return status is 127.  Otherwise, the return status
#               is the exit status of the last process or job waited for.
#
# L
# r option is supplied at
#        invocation,  the  shell becomes restricted.  A restricted shell is used
#        to set up an environment more controlled than the standard  shell.   It
# h with the exception that the following are
#        disallowed or not performed:
#
# d
#
# V
#
# /
#
# .
#               builtin command
#
#        ·      specifying  a  filename containing a slash as an argument to the
# h builtin command
#
#        ·      importing function definitions from  the  shell  environment  at
#               startup
#
# S from the shell environment at
#               startup
#
#        ·      redirecting output using the >, >|, <>, >&, &>, and >> redirect‐
#               ion operators
#
# c builtin command to replace the shell with another
#               command
#
# d  options
# e builtin command
#
# e  builtin  command  to  enable  disabled shell
#               builtins
#
# d builtin command
#
# d.
#
#        These restrictions are enforced after any startup files are read.
#
# ‐
# h turns off any restrictions in the shell
#        spawned to execute the script.
#
# O
# l, Brian Fox and Chet Ramey
# y, Brian Fox and Chet Ramey
# y, Brian Fox and Chet Ramey
# ‐
# s, IEEE --
#               http://pubs.opengroup.org/onlinepubs/9699919799/
#        http://tiswww.case.edu/~chet/bash/POSIX -- a description of posix mode
# h(1)
# i(1)
# e(3)
#
# S
# h
# h executable
# e
#               The systemwide initialization file, executed for login shells
# c
#               The systemwide per-interactive-shell startup file
# t
#               The  systemwide  login shell cleanup file, executed when a login
#               shell exits
# e
#               The personal initialization file, executed for login shells
# c
#               The individual per-interactive-shell startup file
# t
#               The individual login shell cleanup file, executed when  a  login
#               shell exits
# c
# e initialization file
#
# S
#        Brian Fox, Free Software Foundation
#        bfox@gnu.org
#
#        Chet Ramey, Case Western Reserve University
#        chet.ramey@case.edu
#
# S
# , you should report it.  But first, you should
#        make sure that it really is a bug, and that it appears  in  the  latest
# h.   The  latest  version  is  always  available  from
# /.
#
# g
#        command  to submit a bug report.  If you have a fix, you are encouraged
#        to mail that as well!  Suggestions and `philosophical' bug reports  may
# g  or  posted  to  the  Usenet newsgroup
# g.
#
#        ALL bug reports should include:
#
# h
#        The hardware and operating system
#        The compiler used to compile
#        A description of the bug behaviour
#        A short script or `recipe' which exercises the bug
#
# g inserts the first three items automatically into  the  template
#        it provides for filing a bug report.
#
#        Comments and bug reports concerning this manual page should be directed
# u.
#
# S
#        It's too big and too slow.
#
# h and traditional versions
# X specification.
#
#        Aliases are confusing in some uses.
#
#        Shell builtin commands and functions are not stoppable/restartable.
#
#        Compound commands and command sequences of the form `a ; b ; c' are not
#        handled gracefully  when  process  suspension  is  attempted.   When  a
#        process  is stopped, the shell immediately executes the next command in
#        the sequence.  It suffices to place the sequence  of  commands  between
#        parentheses  to  force  it  into  a subshell, which may be stopped as a
#        unit.
#
#        Array variables may not (yet) be exported.
#
#        There may be only one active coprocess at a time.
#
# GNU Bash 4.3                    2014 February 2                        BASH(1)

# %% [markdown]
#   * Bash reference manual: `www.gnu.org/software/bash/manual/bashref.html`
#
#   * "Advanced Bash-Scripting Guide": `http://www.tldp.org/LDP/abs/html/`

# %% [markdown]
# ## What Bash is *good* for
#
# * File and directory management
#
# * Systems management (build scripts)
#
# * Combining other scripts and commands
#
# * Rapid prototyping of more advanced scripts
#
# * Very simple output processing, plotting etc.

# %% [markdown]
# ## What Bash is *not good* for
#
# * Cross-platform portability
#
# * Graphics, GUIs
#
# * Interface with libraries or legacy code
#
# * More advanced post processing and plotting
#
# * Calculations, math etc.

# %% [markdown]
# ## Some common tasks in Bash
#
#   * file writing
#
#   * for-loops
#
#   * running an application
#
#   * pipes
#
#   * writing functions
#
#   * file globbing, testing file types
#
#   * copying and renaming files, creating and moving to directories, creating directory paths, removing files and directories
#
#   * directory tree traversal
#
#   * packing directory trees

# %% [markdown]
# ### Bash example 1: Hello world

# %%
#!/bin/bash
echo "Hello world"
# Out:
# Hello world

# %% [markdown]
# Two options to run this script:
#
# 1. Type the commands directly in the bash shell (only feasible for
# small scripts).
# 2. Save the code as `helloworld.sh` and run with:
# ```bash
# chmod a+x helloworld.sh # Make script executable
# ./helloworld.sh
# ```

# %% [markdown]
# ### Bash example 2: Hello world, v2

# %%
#!/bin/bash
x="world"
echo "Hello ${x}!"
# Out:
# Hello world!

# %% [markdown]
# ## Bash variables and commands
#
#   * Assign a variable by
#     `
#     x=3.4
#     `,
#     retrieve the value of the variable by `$x` (also called **variable substitution**).
#
#   * Variables passed as command line arguments when running a script are called **positional parameters**.
#
#   * Bash has a number of built in commands, type `help` or `help | less` to see all.

# %%
help
# Out:
# GNU bash, version 4.3.48(1)-release (x86_64-pc-linux-gnu)
# These shell commands are defined internally.  Type `help' to see this list.
# Type `help name' to find out more about the function `name'.
# Use `info bash' to find out more about the shell in general.
# Use `man -k' or `info' to find out more about commands not in this list.
#
# A star (*) next to a name means that the command is disabled.
#
#  job_spec [&]                            history [-c] [-d offset] [n] or hist>
#  (( expression ))                        if COMMANDS; then COMMANDS; [ elif C>
#  . filename [arguments]                  jobs [-lnprs] [jobspec ...] or jobs >
#  :                                       kill [-s sigspec | -n signum | -sigs>
#  [ arg... ]                              let arg [arg ...]
#  [[ expression ]]                        local [option] name[=value] ...
#  alias [-p] [name[=value] ... ]          logout [n]
#  bg [job_spec ...]                       mapfile [-n count] [-O origin] [-s c>
#  bind [-lpsvPSVX] [-m keymap] [-f file>  popd [-n] [+N | -N]
#  break [n]                               printf [-v var] format [arguments]
#  builtin [shell-builtin [arg ...]]       pushd [-n] [+N | -N | dir]
#  caller [expr]                           pwd [-LP]
#  case WORD in [PATTERN [| PATTERN]...)>  read [-ers] [-a array] [-d delim] [->
#  cd [-L|[-P [-e]] [-@]] [dir]            readarray [-n count] [-O origin] [-s>
#  command [-pVv] command [arg ...]        readonly [-aAf] [name[=value] ...] o>
#  compgen [-abcdefgjksuv] [-o option]  >  return [n]
#  complete [-abcdefgjksuv] [-pr] [-DE] >  select NAME [in WORDS ... ;] do COMM>
#  compopt [-o|+o option] [-DE] [name ..>  set [-abefhkmnptuvxBCHP] [-o option->
#  continue [n]                            shift [n]
#  coproc [NAME] command [redirections]    shopt [-pqsu] [-o] [optname ...]
#  declare [-aAfFgilnrtux] [-p] [name[=v>  source filename [arguments]
#  dirs [-clpv] [+N] [-N]                  suspend [-f]
#  disown [-h] [-ar] [jobspec ...]         test [expr]
#  echo [-neE] [arg ...]                   time [-p] pipeline
#  enable [-a] [-dnps] [-f filename] [na>  times
#  eval [arg ...]                          trap [-lp] [[arg] signal_spec ...]
#  exec [-cl] [-a name] [command [argume>  true
#  exit [n]                                type [-afptP] name [name ...]
#  export [-fn] [name[=value] ...] or ex>  typeset [-aAfFgilrtux] [-p] name[=va>
#  false                                   ulimit [-SHabcdefilmnpqrstuvxT] [lim>
#  fc [-e ename] [-lnr] [first] [last] o>  umask [-p] [-S] [mode]
#  fg [job_spec]                           unalias [-a] name [name ...]
#  for NAME [in WORDS ... ] ; do COMMAND>  unset [-f] [-v] [-n] [name ...]
#  for (( exp1; exp2; exp3 )); do COMMAN>  until COMMANDS; do COMMANDS; done
#  function name { COMMANDS ; } or name >  variables - Names and meanings of so>
#  getopts optstring name [arg]            wait [-n] [id ...]
#  hash [-lr] [-p pathname] [-dt] [name >  while COMMANDS; do COMMANDS; done
#  help [-dms] [pattern ...]               { COMMANDS ; }

# %% [markdown]
#   * The real power comes from all the available Unix commands, in addition to your own applications and scripts.

# %% [markdown]
# ## Quiz: What is the difference?

# %%
x=5
echo $x

# %%
x = 5
echo $x
# Out:
# x: command not found

# %% [markdown]
# ## Bash variables (1)
#
#
# Variables in Bash are untyped!

# %%
x=5

# %% [markdown]
# Generally treated as character arrays:

# %%
x=$x+1
echo $x
# Out:
# 5+1

# %% [markdown]
# Use the `let` command for simple arithmetic and other operations:

# %%
x=5
let "x+=1"   # let evaluates arithmetic expressions
echo $x
# Out:
# 6

# %% [markdown]
# Variables can be explicitly declared to integer or array:

# %%
declare -i i     # i is an integer
declare -a A     # A is an array
r=10
declare -r r     # r is read only
# Out:
# bash: r: readonly variable

# %%
r="a"
# Out:
# bash: r: readonly variable

# %% [markdown]
# ## Bash variables (2)
#
#
# The `echo` command is used for writing:
# ```bash
# s=42
# echo "The answer is $s"
# ```
# and variables can be inserted in the text string (variable interpolation)

# %% [markdown]
# #### Frequently seen variables
#
#
# Command line arguments:
# ```bash
# $0    # Name of script
# $1    # First command line argument
# $2    # Second command line argument
# # ...
# ```

# %% [markdown]
# All the command line arguments:
# ```bash
# $@
# ```

# %% [markdown]
# Numer of command line arguments:
# ```bash
# $#
# ```

# %% [markdown]
# The exit status of the last executed command:
# ```bash
# $?   # returns 0 if the last command was success
# ```

# %% [markdown]
# ### Example
#
#
# **Idea**: Write a script that takes a command as an argument, runs it and checks if it was succesfull.

# %% [markdown]
# ```bash
# # run_and_test.sh
# $@
#
# if [ "$?" == "0" ]; then
#     echo "Hurray, everything went fine."
# else
#     echo "Oops, there was an error."
# fi
#
# ```

# %%
./run_and_test.sh ls hello-world/*.cpp
# Out:
# hello-world/c++.cpp
# Hurray, everything went fine.

# %% [markdown]
# ## Bash variables (3)
#
#
# Comparison of two integers use a syntax different from comparison of two strings:

# %% [markdown]
# ```bash
# if [ $i -eq 10 ]; then        # integer comparison
#
# fi
#
# if [ "$name" == "10" ]; then  # string  comparison
#
# fi
# ```

# %% [markdown]
# Unless you have declared a variable to be an integer, assume that all variables are strings and use double quotes (strings) when comparing variables in an if test

# %% [markdown]
# ```bash
# if [ "$?" != "0" ]; then  # this is safe
# ```

# %% [markdown]
# ```bash
# if [  $?  !=  0  ]; then  # might be unsafe
# ```

# %% [markdown]
# ### Executing a command, storing the result as a variable

# %% [markdown]
# Can we done in two ways:
# ```bash
# time=$(date)
# time=`date`
# ```

# %% [markdown]
# ## Convenient debugging tool: -x
#
#
# Each source code line is printed prior to its execution if you add -x as option to `/bin/sh` or `/bin/bash`
#
# Either in the header

# %% [markdown]
# ```bash
# #!/bin/bash -x
# ```

# %% [markdown]
# or on the command line:

# %%
bash -x hw.sh
# Out:
# + echo 'Hello World'
# Hello World

# %% [markdown]
# Very convenient during debugging

# %% [markdown]
# ## Combining bash commands (1)
#
#   * The power of Unix lies in combining simple commands into powerful operations
#
#   * Standard bash commands and unix applications normally do one small task
#
#   * Text is used for input and output - easy to send output from one command as input to another

# %% [markdown]
# ## Combining bash commands (2)
# Two standard ways to combine commands:
#
#
# The pipe, sends the output of one command as input to the next:

# %% [markdown]
# ```bash
# ls -l | grep 3331
# ```

# %% [markdown]
# Will list all files having 3331 as part of the name

# %% [markdown]
# ## Combining bash commands (3)
# #### More usefull pipe examples
#
# Send files with size to `sort -rn` (reverse numerical sort) to get a list
# of files sorted after their sizes:

# %% [markdown]
# ```bash
# ls -s | sort -rn
# ```

# %% [markdown]
# Make a new application: sort all files in a directory
# tree `assignments`, with the largest files appearing first, and
# equip the output with paging functionality:

# %% [markdown]
# ```bash
# du -a assignments | sort -rn | less
# ```

# %% [markdown]
# ## Bash redirects
#
# Redirects are used to pass output to either a file or stream.

# %% [markdown]
# ```bash
# echo "Hei verden" > myfile.txt  # Save (stdout) output to file
# echo "Hei verden" >> myfile.txt # Append (stdout) output to file
# wc -w < myfile.txt              # Use file content as (stdin) command input
# ```

# %% [markdown]
# ## Quiz: Can you simplify this code?

# %% [markdown]
# ```bash
# ls > files && grep 2017 < files
# ```

# %% [markdown]
# The code above implements a (inefficient) pipe. Better:
# ```bash
# ls | grep 2017
# ```

# %% [markdown]
# ## Quiz: Can you simplify this code?

# %% [markdown]
# ```bash
# cat INF3331-$username | ./test
# ```

# %% [markdown]
# The above can also be implemented as a:

# %% [markdown]
# ```bash
# ./test < INF3331-$username
# ```

# %% [markdown]
# ## The in-/outputs of a shell process: stdin, stdout and stderr

# %% [markdown]
# A process takes standard input (STDIN) and returns
#
# * standard output (STDOUT)
# * standard error (STDERR)
# * return code - 0 on success, a different number otherwise

# %% [markdown]
# <img src="figs/bash_process_codes.jpg" style="width: 500px;"/>

# %% [markdown]
# ## Redirecting process streams

# %% [markdown]
# ```bash
# rm -v *.txt                 # stdout and stderr are displayed on the terminal
# rm -v *.txt 1> out.txt      # Redirect stout to a file, same as >
# rm -v *.txt 2> err.txt      # Redirect stderr to a file
# rm -v *.txt &> outerr.txt   # Redirect stdout and stderr to file
# ```

# %% [markdown]
# You can print to `stderr` with:

# %% [markdown]
# ```bash
# echo "Wrong arguments" >&2
# ```

# %% [markdown]
# Redirects and pipes can be combined:

# %% [markdown]
# ```bash
# ./compile 2>&1 | less  # View both stdout and stderr in less
# ```

# %% [markdown]
# ## Example: the classical Unix script
# A combination of commands, or a single long command, that you use often:

# %% [markdown]
# ```bash
# ./pulse_app -cmt WinslowRice -casename ellipsoid < ellipsoid.i | tee main_output
# ```

# %% [markdown]
# In this case, flexibility is often not a high priority.
#
# However, there
# is room for improvement;
#
#   * Not possible to change command line options, input and output files
#
#   * Output file `main_output` is overwritten for each run
#
#   * Can we edit the input file for each run?

# %% [markdown]
# ## Problem 1: changing application input
# In many cases only one parameter is changed frequently:

# %% [markdown]
# ```bash
# CASE='testbox'
# CMT='WinslowRice'
# if [ $# -gt 0 ]; then
#    CMT=$1
# fi
# INFILE='ellipsoid_test.i'
# OUTFILE='main_output'
#
# ./pulse_app -cmt $CMT -cname $CASE < $INFILE | tee $OUTFILE
# ```

# %% [markdown]
# Still not very flexible, but in many cases sufficient. More
# flexibility requires more advanced parsing of command line options,
# which will be introduced later.

# %% [markdown]
# ## Problem 2: overwriting output file
#
#
# A simple solution is to add the output file as a command line
#   option, but what if we forget to change this from one run to the
#   next?
#
# Simple solution to ensure data is never over-written:

# %% [markdown]
# ```bash
# jobdir=$PWD/$(date)
# mkdir $jobdir
# cd $jobdir
#
# ./pulse_app -cmt $CMT -cname $CASE  < $INFILE | tee $OUTFILE
# cd ..
# if [ -L 'latest' ]; then
#     rm latest
# fi
# ln -s $jobdir latest
# ```

# %% [markdown]
# ## Problem 2: overwriting output file (2)
# Alternative solutions:
#
# * Use process ID of the script (`$$`, not really unique)
#
# * `mktemp` can create a temporary file with a unique name, for
#   use by the script
#
# * Check if subdirectory exists, exit script if it does:

# %% [markdown]
# ```bash
# dir=$case
# # check if $dir is a directory:
# if [ -d $dir ]
#   # exit script to avoid overwriting data
#   then
#     echo "Output directory exists, provide a different name"
#     exit
# fi
# mkdir $dir   # create new directory $dir
# cd $dir      # move to $dir
# ```

# %% [markdown]
# ## Alternative `if`-tests
# As with everything else in Bash, there are multiple ways to do `if`-tests:

# %% [markdown]
# ```bash
# # the 'then' statement can also appear on the 1st line:
# if [ -d $dir ];
# then
#   exit
# fi
#
# # another form of if-tests:
# if test -d $dir; then
#   exit
# fi
#
# # and a shortcut:
# [ -d $dir ] && exit
# test -d $dir && exit
# ```

# %% [markdown]
# Be aware of the whitespaces in the `[ -d $dir ]`, otherwise it will not work.

# %% [markdown]
# ## Problem 3: can we edit the input file at run time?
#
#   * Some applications do not take command line options, all input must read from standard input or an input file
#
#   * A Bash script can be used to equip such programs with basic handling of command line options
#
# **Idea**: We want to grab input from the command line, create the correct input file, and run the application

# %% [markdown]
# ## File reading and writing
#
#
# File writing is efficiently done by 'here documents':

# %% [markdown]
# ```bash
# cat > myfile <<EOF
# multi-line text
# can now be inserted here,
# and variable substition such as
# $myvariable is
# supported.
# EOF
# ```

# %% [markdown]
# The final EOF must
# start in column 1 of the
# script file.

# %% [markdown]
# ## Parsing command-line options

# %% [markdown]
# ```bash
# # read variables from the command line, one by one:
# while [ $# -gt 0 ]
# do
#     option=$1; # load command-line arg into option
#     shift;     # eat currently first command-line arg
#     case "$option" in
#         -m)
#             m=$1; shift; ;;  # ;; indicates end of case
#         -b)
#             b=$1; shift; ;;
#         *)
#             echo "$0: invalid option \"$option\""; exit ;;
#     esac
# done
#
# echo "Command line arguments:"
# [ -n "$m" ] && echo "m=$m"
# [ -n "$b" ] && echo "b=$b"
# ```

# %% [markdown]
# ## Alternative to case: if
#
# `case` is standard when parsing command-line arguments in Bash, but if-tests can also be used. Consider

# %% [markdown]
# ```bash
# if [ "$option" == "-m" ]; then
#     m=$1; shift;
# elif [ "$option" == "-b" ]; then
#     b=$1; shift;
# else
#     echo exit;
# fi
# ```

# %% [markdown]
# ## After assigning variables, we can write the input file

# %% [markdown]
# Write to `$infile` the lines that appear between the EOF symbols:
#
# ```bash
# cat > $infile <<EOF
#         gridfile='test2.grid'
#         param_m=$m
#         param_b=$b
# EOF
# ```

# %% [markdown]
# ## Then execute the program as usual
#
#
# Redirecting input to read from the new input file

# %% [markdown]
# ```bash
# ../pulse_app < $infile
# ```

# %% [markdown]
# We can add a check for successful execution.
# The shell variable `$?` is 0 if last command
# was successful, otherwise `$? != 0`.

# %% [markdown]
# ```bash
# if [ "$?" != "0" ]; then
#   echo "running pulse_app failed"; exit 1
# fi
#
# # exit n sets $? to n
# ```

# %% [markdown]
# ## For-loops
#
#
# What if we want to run the application for multiple input files?

# %% [markdown]
# ```bash
# ./run.sh test1.i test2.i test3.i test4.i
# ```

# %% [markdown]
# or

# %% [markdown]
# ```bash
# ./run.sh *.i
# ```

# %% [markdown]
# A for-loop over command line arguments

# %% [markdown]
# ```bash
# for arg in $@; do
#   ../pulse_app < $arg
# done
# ```

# %% [markdown]
# Can be combined with more advanced command line options, output
#   directories, etc...

# %% [markdown]
# ## For-loops (2)
#
#
# For loops for file management:

# %% [markdown]
# ```bash
# files=`ls *.tmp`
#
# for file in $files
# do
#   echo removing $file
#   rm -f $file
# done
# ```

# %% [markdown]
# ## Counters
#
#
# Declare an integer counter:

# %% [markdown]
# ```bash
# declare -i counter
# counter=0
# # arithmetic expressions must appear inside (( ))
# ((counter++))
# echo $counter  # yields 1
# ```

# %% [markdown]
# For-loop with counter:

# %% [markdown]
# ```bash
# declare -i n; n=1
# for arg in $@; do
#   echo "command-line argument no. $n is <$arg>"
#   ((n++))
# done
# ```

# %% [markdown]
# ## C-style for-loops

# %% [markdown]
# ```bash
# declare -i i
# for ((i=0; i<$n; i++)); do
#   echo $c
# done
# ```

# %% [markdown]
# ## Example: bundle files
#
#
# Pack a series of files into one file
#
# Executing this single file as a Bash script packs out all the individual files again
#
# Usage:

# %% [markdown]
# ```bash
# bundle file1 file2 file3 > onefile  # pack
# bash onefile # unpack
# ```

# %% [markdown]
# Writing `bundle` is easy:

# %% [markdown]
# ```bash
# #/bin/sh
# for i in $@; do
#     echo "echo unpacking file $i"
#     echo "cat > $i <<EOF"
#     cat $i
#     echo "EOF"
# done
# ```

# %% [markdown]
# ## The bundle output file
#
#
# Consider 2 fake files: `file1`:

# %% [markdown]
# ```bash
# Hello, World!
# No sine computations today
# ```

# %% [markdown]
# and `file2`:

# %% [markdown]
# ```bash
# 1.0 2.0 4.0
# 0.1 0.2 0.4
# ```

# %% [markdown]
# Running `bundle file1 file2` yields the output

# %% [markdown]
# ```bash
# echo unpacking file file1
# cat > file1 <<EOF
# Hello, World!
# No sine computations today
# EOF
# echo unpacking file file2
# cat > file2 <<EOF
# 1.0 2.0 4.0
# 0.1 0.2 0.4
# EOF
# ```

# %% [markdown]
# ## Running an application
#
#
# Running in the foreground:

# %% [markdown]
# ```bash
# cmd="myprog -c file.1 -p -f -q";
# $cmd < my_input_file
#
# # output is directed to the file res
# $cmd < my_input_file > res
#
# # process res file by Sed, Awk, Perl or Python
# ```

# %% [markdown]
# Running in the background:

# %% [markdown]
# ```bash
# myprog -c file.1 -p -f -q < my_input_file &
# ```

# %% [markdown]
# or stop a foreground job with Ctrl-Z and then type `bg`

# %% [markdown]
# ## Functions

# %% [markdown]
# ```bash
# function system {
# # Run operating system command and if failure, report and abort
#
#   "$@"
#   if [ $? -ne 0 ]; then
#     echo "make.sh: unsuccessful command $@"
#     echo "abort!"
#     exit 1
#   fi
# }
# # function arguments: $1 $2 $3 and so on
# # return value: last statement
# # call:
# name=mydoc
# system pdflatex $name
# system bibtex $name
# ```

# %% [markdown]
# How to return a value from a function? Define a new variable within the function - all functions are global!

# %% [markdown]
# ## File globbing, for loop on the command line
#
#
# List all .ps and .gif files using wildcard notation:

# %% [markdown]
# ```bash
# files=`ls *.ps *.gif`
#
# # or safer, if you have aliased ls:
# files=`/bin/ls *.ps *.gif`
#
# # compress and move the files:
# gzip $files
# for file in $files; do
#   mv ${file}.gz $HOME/images
# ```

# %% [markdown]
# ## Testing file types

# %% [markdown]
# ```bash
# if [ -f $myfile ]; then
#     echo "$myfile is a plain file"
# fi
#
# # or equivalently:
# if test -f $myfile; then
#     echo "$myfile is a plain file"
# fi
#
# if [ ! -d $myfile ]; then
#     echo "$myfile is NOT a directory"
# fi
#
# if [ -x $myfile ]; then
#     echo "$myfile is executable"
# fi
#
# [ -z $myfile ] && echo "empty file $myfile"
# ```

# %% [markdown]
# ## Rename, copy and remove files

# %% [markdown]
# ```bash
# # rename $myfile to tmp.1:
# mv $myfile tmp.1
#
# # force renaming:
# mv -f $myfile tmp.1
#
# # move a directory tree my tree to $root:
# mv mytree $root
#
# # copy myfile to $tmpfile:
# cp myfile $tmpfile
#
# # copy a directory tree mytree recursively to $root:
# cp -r mytree $root
#
# # remove myfile and all files with suffix .ps:
# rm myfile *.ps
#
# # remove a non-empty directory tmp/mydir:
# rm -r tmp/mydir
# ```

# %% [markdown]
# ## Directory management

# %% [markdown]
# ```bash
# # make directory:
# $dir = "mynewdir";
# mkdir $mynewdir
# mkdir -m 0755 $dir  # readable for all
# mkdir -m 0700 $dir  # readable for owner only
# mkdir -m 0777 $dir  # all rights for all
#
# # move to $dir
# cd $dir
# # move to $HOME
# cd
#
# # create intermediate directories (the whole path):
# mkdir -p  $HOME/bash/prosjects/test1
# ```

# %% [markdown]
# ## The find command
#
# Very useful command!
#
#
# `find` visits all files in a directory tree and can execute one or more commands for every file
#
# Basic example: find the `oscillator` codes

# %% [markdown]
# ```bash
# find $scripting/src -name 'oscillator*' -print
# ```

# %% [markdown]
# Or find all PostScript files

# %% [markdown]
# ```bash
# find $HOME \( -name '*.ps' -o -name '*.eps' \) -print
# ```

# %% [markdown]
# We can also run a command for each file:

# %% [markdown]
# ```bash
# find rootdir -name filenamespec -exec command {} \; -print
# # {} is the current filename
# ```

# %% [markdown]
# ## Applications of find (1)
#
#
# Find all files larger than 2000 blocks a 512 bytes (=1Mb):

# %% [markdown]
# ```bash
# find $HOME -name '*' -type f -size +2000 -exec ls -s {} \;
# ```

# %% [markdown]
# Remove all these files:

# %% [markdown]
# ```bash
# find $HOME -name '*' -type f -size +2000 \
#            -exec ls -s {} \; -exec rm -f {} \;
# ```

# %% [markdown]
# or ask the user for permission to remove:

# %% [markdown]
# ```bash
# find $HOME -name '*' -type f -size +2000 \
#            -exec ls -s {} \; -ok rm -f {} \;
# ```

# %% [markdown]
# ## Applications of find (2)
#
#
# Find all files not being accessed for the last 90 days:

# %% [markdown]
# ```bash
# find $HOME -name '*' -atime +90 -print
# ```

# %% [markdown]
# and move these to /tmp/trash:

# %% [markdown]
# ```bash
# find $HOME -name '*' -atime +90 -print \
#            -exec mv -f {} /tmp/trash \;
# ```

# %% [markdown]
# ## Tar and gzip
#
#
# The `tar` command can pack single files or  all files in a directory tree into one file, which can be unpacked later

# %% [markdown]
# ```bash
# tar -cvf myfiles.tar mytree file1 file2
#
# # options:
# # c: pack, v: list name of files, f: pack into file
#
# # unpack the mytree tree and the files file1 and file2:
# tar -xvf myfiles.tar
#
# # options:
# # x: extract (unpack)
# ```

# %% [markdown]
# The tarfile can be compressed:

# %% [markdown]
# ```bash
# gzip mytar.tar
# # result: mytar.tar.gz
# ```

# %% [markdown]
# ## Two find/tar/gzip examples
#
#
# Pack all PostScript figures:

# %% [markdown]
# ```bash
# tar -cvf ps.tar `find $HOME -name '*.ps' -print`
# gzip ps.tar
# ```

# %% [markdown]
# Pack a directory but remove CVS directories and redundant files

# %% [markdown]
# ```bash
# # take a copy of the original directory:
# cp -r myhacks /tmp/oblig1-hpl
# # remove CVS directories
# find /tmp/oblig1-hpl -name CVS -print -exec rm -rf {} \;
# # remove redundant files:
# find /tmp/oblig1-hpl \( -name '*~' -o -name '*.bak' \
#  -o -name '*.log' \) -print -exec rm -f {} \;
# # pack files:
# tar -cf oblig1-hpl.tar /tmp/tar/oblig1-hpl.tar
# gzip oblig1-hpl.tar
# # send oblig1-hpl.tar.gz as mail attachment
# ```
